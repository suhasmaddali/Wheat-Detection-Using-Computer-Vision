# %%
import pandas as pd

# %%
df_train = pd.read_csv('../input/global-wheat-detection/train.csv')

# %%
df_train.head()

# %%
df_train.describe()

# %%
df_train.info()

# %%
import missingno as msno

# %%
msno.matrix(df_train)

# %%
df_train['source'].value_counts()

# %%
df_train[]

# %%
import seaborn as sns

# %%
sns.barplot(x = 'source', y = va)
